# %%
# products  = ["CANE","CORN","IYR","SOYB","TLT","WEAT","XLB","XLE","XLF","XLI","XLK","XLP","XLU","XLV","XOP","XRT","XTL"]
products  = ["IYR","XLB","XLE","XLF","XLI","XLK","XLP","XLU","XLV","XOP","XRT","XTL"]

# %%
len(products)
# Out:
# 12

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# loop over the list of csv files
products  = ["IYR","XLB","XLE","XLF","XLI","XLK","XLP","XLU","XLV","XOP","XRT","XTL"] # ,asofdate,pnl,strategy,positionType,position_identifier
merge_lst = []

path      = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
  

for product in products:
    
    for f in csv_files:
        if product+"_pnl" in f:
            pnl_df = pd.read_csv(f)      
            pnl_df['product_name'] = [product]*len(pnl_df)     

            close_df = pd.read_csv(product+'.csv')

            result = pd.merge(close_df[['Date','Close','Dividends','Stock Splits']], 
                            pnl_df[['asofdate', 'pnl','strategy','positionType','position_identifier']],
                            left_on='Date',
                            right_on='asofdate',
                            how='inner')

            merge_lst.append(result)

merge_df = pd.concat(merge_lst,axis=0).reset_index()

# saving the position ticker
cache_position_ticker = []

i = 0
while i < len(merge_df):

    cache_position_ticker.append(merge_df['position_identifier'][i].split("_")[0])

    i+=1

merge_df['product_name'] = cache_position_ticker

# save the position entry date

merge_df['position_identifier'].unique()

start_date = []

for position in merge_df['position_identifier'].unique():

    date = merge_df[merge_df['position_identifier'] == position].reset_index()['Date'][0]

    i = 0
    while i < len(merge_df[merge_df['position_identifier'] == position]):

        start_date.append(date)    

        i+=1

merge_df['entry_date'] = start_date

merge_df.reset_index()
# Out:
#        level_0  index                       Date      Close  Dividends  \
# 0            0      0  2019-05-15 00:00:00-04:00  78.588486        0.0
# 1            1      1  2019-05-16 00:00:00-04:00  79.054413        0.0
# 2            2      2  2019-05-17 00:00:00-04:00  78.830399        0.0
# 3            3      3  2019-05-20 00:00:00-04:00  77.665596        0.0
# 4            4      4  2019-05-21 00:00:00-04:00  78.319695        0.0
# ...        ...    ...                        ...        ...        ...
# 10855    10855    900  2022-12-08 00:00:00-05:00  84.677635        0.0
# 10856    10856    901  2022-12-09 00:00:00-05:00  83.640244        0.0
# 10857    10857    902  2022-12-12 00:00:00-05:00  84.587868        0.0
# 10858    10858    903  2022-12-13 00:00:00-05:00  85.006813        0.0
# 10859    10859    904  2022-12-14 00:00:00-05:00  84.707565        0.0
#
#        Stock Splits                   asofdate       pnl strategy  \
# 0               0.0  2019-05-15 00:00:00-04:00  0.322548  arma_ma
# 1               0.0  2019-05-16 00:00:00-04:00  0.510727  arma_ma
# 2               0.0  2019-05-17 00:00:00-04:00  0.465927  arma_ma
# 3               0.0  2019-05-20 00:00:00-04:00 -0.224014  arma_ma
# 4               0.0  2019-05-21 00:00:00-04:00 -1.164803  arma_ma
# ...             ...                        ...       ...      ...
# 10855           0.0  2022-12-08 00:00:00-05:00  0.000000  arma_ma
# 10856           0.0  2022-12-09 00:00:00-05:00  0.000000  arma_ma
# 10857           0.0  2022-12-12 00:00:00-05:00  0.000000  arma_ma
# 10858           0.0  2022-12-13 00:00:00-05:00  0.000000  arma_ma
# 10859           0.0  2022-12-14 00:00:00-05:00  0.000000  arma_ma
#
#       positionType  position_identifier product_name  \
# 0             long           IYR_long_0          IYR
# 1             long           IYR_long_0          IYR
# 2             long           IYR_long_0          IYR
# 3             long           IYR_long_0          IYR
# 4             long           IYR_long_0          IYR
# ...            ...                  ...          ...
# 10855  no_position  XTL_no_position_900          XTL
# 10856  no_position  XTL_no_position_900          XTL
# 10857  no_position  XTL_no_position_900          XTL
# 10858  no_position  XTL_no_position_900          XTL
# 10859  no_position  XTL_no_position_900          XTL
#
#                       entry_date
# 0      2019-05-15 00:00:00-04:00
# 1      2019-05-15 00:00:00-04:00
# 2      2019-05-15 00:00:00-04:00
# 3      2019-05-15 00:00:00-04:00
# 4      2019-05-15 00:00:00-04:00
# ...                          ...
# 10855  2022-12-08 00:00:00-05:00
# 10856  2022-12-08 00:00:00-05:00
# 10857  2022-12-08 00:00:00-05:00
# 10858  2022-12-08 00:00:00-05:00
# 10859  2022-12-08 00:00:00-05:00
#
# [10860 rows x 13 columns]

# %%
merge_df.reset_index()
products  = ["IYR","XLB","XLE","XLF","XLI","XLK","XLP","XLU","XLV","XOP","XRT","XTL"] 

portfolio_value = 100000
position_size   = 1/len(products)

hist_portfolio_value = []
position_scaled_df   = []
updated_position_lst = []

for date in merge_df['entry_date'].unique():

    
    position_scaled_df   = []
    # updated_position_lst = []
    for position in  merge_df[merge_df['entry_date'] == date]['position_identifier'].unique():

        position_df = merge_df[(merge_df['position_identifier'] == position)]
        position_df.reset_index(inplace=True)

        scale         = []
        portfolio_lst = []

        i = 0
        while i < len(position_df):

            if position_df['positionType'][i] == 'long':
                scale.append(2*np.floor(portfolio_value*position_size/position_df['Close'][0]))

            if position_df['positionType'][i] == 'short':
                scale.append(np.floor(portfolio_value*position_size/position_df['Close'][0]))

            if position_df['positionType'][i] == 'no_position':
                scale.append(np.floor(portfolio_value*position_size/position_df['Close'][0]))

            portfolio_lst.append(portfolio_value)

            i+=1

        position_df['scale']           = scale
        position_df['rescaled_pnl']    = position_df['scale']*position_df['pnl']
        position_df['portfolio_value'] = portfolio_lst
 
        position_scaled_df.append(position_df)

    updated_position_df = pd.concat(position_scaled_df,axis = 0)
    portfolio_value     = portfolio_value + updated_position_df['rescaled_pnl'].sum()

    updated_position_lst.append(pd.concat(position_scaled_df,axis = 0))

    # hist_portfolio_value.append(portfolio_value)
# Out:
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
portfolio_df = pd.concat(updated_position_lst,axis=0)

# %%
test_df = portfolio_df.groupby('Date').sum()

# %%
test_df['rescaled_pnl'].cumsum()
# Out:
# Date
# 2019-05-15 00:00:00-04:00      -373.349480
# 2019-05-16 00:00:00-04:00      -193.977100
# 2019-05-17 00:00:00-04:00      -101.942181
# 2019-05-20 00:00:00-04:00       202.912083
# 2019-05-21 00:00:00-04:00       127.053730
#                                  ...
# 2022-12-08 00:00:00-05:00    531326.776823
# 2022-12-09 00:00:00-05:00    532264.244047
# 2022-12-12 00:00:00-05:00    530921.783415
# 2022-12-13 00:00:00-05:00    532024.256498
# 2022-12-14 00:00:00-05:00    532346.746977
# Name: rescaled_pnl, Length: 905, dtype: float64

# %%
(532346.746977/100000)**(1/3.59) -1
# Out:
# 0.5932452033293241

# %%
905/252
# Out:
# 3.5912698412698414

# %%
test_df_pnl = test_df['rescaled_pnl'].cumsum()

# %%
test_df_pnl.to_csv(r'final_pnl.csv')

# %%
plt.figure(figsize=(45,15))

plt.plot(test_df['rescaled_pnl'].cumsum())

plt.show()

# %%
drawdown = 100000+ test_df['rescaled_pnl'].cumsum()

# %%
drawdown = drawdown/drawdown.rolling(window=30).max()

# %%
drawdown.to_csv(r'drawdown.csv')

# %%
plt.figure(figsize=(45,15))

plt.plot(drawdown/drawdown.rolling(window=30).max())
plt.axhline(0.95)
plt.axhline(0.975)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.plot(test_df['rescaled_pnl'].cumsum())

plt.show()

# %%
dataframe = portfolio_df[portfolio_df['product_name']=='IYR']

# %%
test = portfolio_df

# %%
test.set_index('Date',inplace=True)

# %%
plt.figure(figsize=(45,15))

for product in portfolio_df['product_name'].unique():
    plt.plot(test[test['product_name'] == product]['rescaled_pnl'].cumsum())

plt.legend(test['product_name'].unique())
plt.show()

# %%
summary_df = portfolio_df.groupby('Date')

# %%
summary_df.to_csv(r'summary.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20024\3525639123.py in <module>
# ----> 1 summary_df.to_csv(r'summary.csv')
#
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     910
#     911         raise AttributeError(
# --> 912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#     914
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_csv'

# %%
summary_df.head()
# Out:
#     level_0  index                       Date       Close  Dividends  \
# 0         0      0  2019-05-15 00:00:00-04:00   78.588486        0.0
# 1         1      1  2019-05-16 00:00:00-04:00   79.054413        0.0
# 2         2      2  2019-05-17 00:00:00-04:00   78.830399        0.0
# 3         3      3  2019-05-20 00:00:00-04:00   77.665596        0.0
# 4         4      4  2019-05-21 00:00:00-04:00   78.319695        0.0
# ..      ...    ...                        ...         ...        ...
# 0      4520    900  2022-12-08 00:00:00-05:00   99.009277        0.0
# 1      4521    901  2022-12-09 00:00:00-05:00   98.196510        0.0
# 2      4522    902  2022-12-12 00:00:00-05:00   99.881516        0.0
# 3      4523    903  2022-12-13 00:00:00-05:00  100.258163        0.0
# 4      4524    904  2022-12-14 00:00:00-05:00  100.069847        0.0
#
#     Stock Splits                   asofdate       pnl strategy positionType  \
# 0            0.0  2019-05-15 00:00:00-04:00  0.322548  arma_ma         long
# 1            0.0  2019-05-16 00:00:00-04:00  0.510727  arma_ma         long
# 2            0.0  2019-05-17 00:00:00-04:00  0.465927  arma_ma         long
# 3            0.0  2019-05-20 00:00:00-04:00 -0.224014  arma_ma         long
# 4            0.0  2019-05-21 00:00:00-04:00 -1.164803  arma_ma         long
# ..           ...                        ...       ...      ...          ...
# 0            0.0  2022-12-08 00:00:00-05:00  0.000000  arma_ma  no_position
# 1            0.0  2022-12-09 00:00:00-05:00  0.000000  arma_ma  no_position
# 2            0.0  2022-12-12 00:00:00-05:00  0.000000  arma_ma  no_position
# 3            0.0  2022-12-13 00:00:00-05:00  0.000000  arma_ma  no_position
# 4            0.0  2022-12-14 00:00:00-05:00  0.000000  arma_ma  no_position
#
#     position_identifier product_name                 entry_date    scale  \
# 0            IYR_long_0          IYR  2019-05-15 00:00:00-04:00    318.0
# 1            IYR_long_0          IYR  2019-05-15 00:00:00-04:00    318.0
# 2            IYR_long_0          IYR  2019-05-15 00:00:00-04:00    318.0
# 3            IYR_long_0          IYR  2019-05-15 00:00:00-04:00    318.0
# 4            IYR_long_0          IYR  2019-05-15 00:00:00-04:00    318.0
# ..                  ...          ...                        ...      ...
# 0   XLI_no_position_900          XLI  2022-12-08 00:00:00-05:00  10729.0
# 1   XLI_no_position_900          XLI  2022-12-08 00:00:00-05:00  10729.0
# 2   XLI_no_position_900          XLI  2022-12-08 00:00:00-05:00  10729.0
# 3   XLI_no_position_900          XLI  2022-12-08 00:00:00-05:00  10729.0
# 4   XLI_no_position_900          XLI  2022-12-08 00:00:00-05:00  10729.0
#
#     rescaled_pnl
# 0     102.570236
# 1     162.411163
# 2     148.164825
# 3     -71.236542
# 4    -370.407211
# ..           ...
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
#
# [4525 rows x 15 columns]

# %%
plt.figure(figsize=(45,15))

plt.plot(summary_df['rescaled_pnl'])

plt.show()

# %%
# portfolio_value = 100000
# position_size   = 1/len(products)

# scale                = []
# hist_portfolio_value = []

# for date in merge_df['Date'].unique():

#     adj_df = merge_df[merge_df['Date'] == date].reset_index()
    
#     scale = []
#     i = 0
#     while i < len(adj_df):

#         if adj_df['positionType'][i] == 'long':
#             scale.append(3*np.floor(portfolio_value*position_size/adj_df['Close'][i]))

#         if adj_df['positionType'][i] == 'short':
#             scale.append(np.floor(portfolio_value*position_size/adj_df['Close'][i]))

#         if adj_df['positionType'][i] == 'no_position':
#             scale.append(np.floor(portfolio_value*position_size/adj_df['Close'][i]))

#         i+=1


#     adj_df['scale']        = scale
#     adj_df['rescaled_pnl'] = adj_df['scale']*adj_df['pnl']

#     adj_df['cumulative_pnl'] = adj_df.groupby(by='Date')['rescaled_pnl'].sum()

# %%
merge_df['scale']        = scale
merge_df['rescaled_pnl'] = merge_df['scale']*merge_df['pnl']

merge_df['cumulative_pnl'] = merge_df.groupby(by='Date')['rescaled_pnl'].sum()

# %%
portfolio_value = 100000
position_size   = 1/len(products)

scale = []

merge_df = merge_df.reset_index()

i = 0
while i < len(merge_df):
    
    if merge_df['positionType'][i] == 'long':
        scale.append(3*np.floor(portfolio_value*position_size/merge_df['Close'][i]))

    if merge_df['positionType'][i] == 'short':
        scale.append(np.floor(portfolio_value*position_size/merge_df['Close'][i]))

    if merge_df['positionType'][i] == 'no_position':
        scale.append(np.floor(portfolio_value*position_size/merge_df['Close'][i]))
        
    i+=1

merge_df['scale']        = scale
merge_df['rescaled_pnl'] = merge_df['scale']*merge_df['pnl']

merge_df['cumulative_pnl'] = merge_df.groupby(by='Date')['rescaled_pnl'].sum()

# %%
merge_df.to_csv('test.csv')

# %%
final_pnl_df = pd.read_csv(r'test.csv',parse_dates=True,index_col='Date')

# %%
final_pnl_df.fillna(0,inplace=True)

# %%
df = final_pnl_df.groupby('Date')['rescaled_pnl'].sum()

# %%
df.head()
# Out:
# Date
# 2019-05-15 00:00:00-04:00   -302.242958
# 2019-05-16 00:00:00-04:00    305.024155
# 2019-05-17 00:00:00-04:00    125.736046
# 2019-05-20 00:00:00-04:00    248.909435
# 2019-05-21 00:00:00-04:00   -185.499027
# Name: rescaled_pnl, dtype: float64

# %%
cum_df = df.cumsum()/100000

# %%
plt.figure(figsize=(45,15))
plt.plot(cum_df)
plt.show()

# %%
plt.figure(figsize=(45,15))
plt.plot(df/100000)
plt.show()

# %%
merge_df.to_csv(r'merge_pnl.csv')
