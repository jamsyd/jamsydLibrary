# %%
import os
import glob

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
merge_lst = []

path      = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))
  
for product in products:
    
    for f in csv_files:
        if "_forecasts" in f:
            df = pd.read_csv(f)      
            merge_lst.append(df)

merge_df = pd.concat(merge_lst,axis=0).reset_index()

# %%
merge_df
# Out:
#          index                       Date                   asofdate  \
# 0            0  2007-02-07 00:00:00-05:00  2007-02-08 00:00:00-05:00
# 1            1  2007-02-08 00:00:00-05:00  2007-02-09 00:00:00-05:00
# 2            2  2007-02-09 00:00:00-05:00  2007-02-12 00:00:00-05:00
# 3            3  2007-02-12 00:00:00-05:00  2007-02-13 00:00:00-05:00
# 4            4  2007-02-13 00:00:00-05:00  2007-02-14 00:00:00-05:00
# ...        ...                        ...                        ...
# 1124955   2745  2022-12-22 00:00:00-05:00  2022-12-23 00:00:00-05:00
# 1124956   2746  2022-12-23 00:00:00-05:00  2022-12-27 00:00:00-05:00
# 1124957   2747  2022-12-27 00:00:00-05:00  2022-12-28 00:00:00-05:00
# 1124958   2748  2022-12-28 00:00:00-05:00  2022-12-29 00:00:00-05:00
# 1124959   2749  2022-12-29 00:00:00-05:00  2022-12-30 00:00:00-05:00
#
#          pointForecast      Close  forecastday product_name      MA_50  \
# 0            15.240592  15.212017            1          XBI  15.334134
# 1            15.190617  15.313515            2          XBI  15.314215
# 2            15.223431  15.170787            3          XBI  15.299117
# 3            15.201865  15.557753            4          XBI  15.293916
# 4            15.216030  15.700480            5          XBI  15.286938
# ...                ...        ...          ...          ...        ...
# 1124955      66.354343  66.563156            1          XTN  70.355460
# 1124956      66.444069  67.301300            2          XTN  70.375690
# 1124957      66.514863  66.672874            3          XTN  70.405268
# 1124958      66.516131  65.685349            4          XTN  70.384611
# 1124959      66.485502  67.361153            5          XTN  70.379538
#
#          MA_diff_50
# 0         -0.021378
# 1         -0.019919
# 2         -0.015098
# 3         -0.005202
# 4         -0.006978
# ...             ...
# 1124955    0.021407
# 1124956    0.020230
# 1124957    0.029579
# 1124958   -0.020657
# 1124959   -0.005073
#
# [1124960 rows x 9 columns]

# %%
merge_df.to_csv('forecast_df.csv')

# %% [markdown]
# # Begin Analysis

# %%
products  = ["XBI","XLB","XLC","XLE","XLF","XLI","XLK","XLP","XLU","XLV","XLU","XLY","XME","XRT","XTL","XTN"]

# %%
forecast_df = merge_df.copy()

# %%
forecast_df['forecast_error'] = forecast_df['Close'] - forecast_df['pointForecast']

# %%
for product in products:
    print(product)

    plt.figure(figsize=(45,15))
    plot_df = forecast_df[forecast_df['product_name'] == product]
    i = 1
    while i < 6:

        plt.hist(forecast_df[forecast_df['forecastday'] == i]['forecast_error'],bins=100)
        print(i,np.mean(forecast_df[forecast_df['forecastday'] == i]['forecast_error']))
        print(i,np.std(forecast_df[forecast_df['forecastday'] == i]['forecast_error']))
        i+=1
    plt.legend(["1","2","3","4","5",])



    plt.show()
# Out:
# XBI
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLB
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLC
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLE
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLF
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLI
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLK
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLP
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLU
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLV
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLU
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XLY
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XME
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XRT
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XTL
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403
# XTN
# 1 -0.019630567717579057
# 1 0.1324980377242829
# 2 -0.008541854709657236
# 2 0.757794839273708
# 3 0.019240712842290314
# 3 1.032563144045
# 4 0.007481578574724881
# 4 1.279621267171731
# 5 0.03423282543924707
# 5 1.4559841352941403

# %%
forecast_df.head()
# Out:
#    index                       Date                   asofdate  pointForecast  \
# 0      0  2007-02-07 00:00:00-05:00  2007-02-08 00:00:00-05:00      15.240592
# 1      1  2007-02-08 00:00:00-05:00  2007-02-09 00:00:00-05:00      15.190617
# 2      2  2007-02-09 00:00:00-05:00  2007-02-12 00:00:00-05:00      15.223431
# 3      3  2007-02-12 00:00:00-05:00  2007-02-13 00:00:00-05:00      15.201865
# 4      4  2007-02-13 00:00:00-05:00  2007-02-14 00:00:00-05:00      15.216030
#
#        Close  forecastday product_name      MA_50  MA_diff_50  forecast_error
# 0  15.212017            1          XBI  15.334134   -0.021378       -0.028575
# 1  15.313515            2          XBI  15.314215   -0.019919        0.122898
# 2  15.170787            3          XBI  15.299117   -0.015098       -0.052644
# 3  15.557753            4          XBI  15.293916   -0.005202        0.355888
# 4  15.700480            5          XBI  15.286938   -0.006978        0.484450
