# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\jamsydLibrary\fcast.csv',parse_dates=True,index_col='time')

# %%
df
# Out:
#             forecast   actuals  forecast_day      origin
# time
# 2010-08-09  1.000206  1.005360             1  2010-08-05
# 2010-08-10  1.003224  0.994891             2  2010-08-05
# 2010-08-11  0.997016  0.968966             3  2010-08-05
# 2010-08-12  1.000166  0.994700             4  2010-08-05
# 2010-08-16  0.997016  1.000929             5  2010-08-05
# ...              ...       ...           ...         ...
# 2013-02-12  0.999470  1.003139             1  2013-02-11
# 2013-02-13  0.999910  0.999012             2  2013-02-11
# 2013-02-14  1.007060  1.001649             3  2013-02-11
# 2013-02-19  1.000661  1.007910             4  2013-02-11
# 2013-02-20  1.002709  0.985612             5  2013-02-11
#
# [500 rows x 4 columns]

# %%
plt.figure(figsize=(45,15))
plt.plot(df['forecast'])
plt.plot(df['actuals'])
plt.legend(['forecast','actuals'],fontsize=30)

plt.show()

# %%
plt.figure(figsize=(45,15))
plt.scatter(df['forecast'],df['actuals'])
# plt.legend(['forecast','actuals'],fontsize=30)

plt.show()
