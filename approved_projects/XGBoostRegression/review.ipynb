# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\jamsydLibrary\fcast.csv',parse_dates=True,index_col='time')

# %%
df
# Out:
#             forecast   actuals  forecast_day      origin
# time
# 2010-08-11  0.999359  0.968966             1  2010-08-10
# 2010-08-12  1.000060  0.994700             2  2010-08-10
# 2010-08-16  0.999435  1.000929             3  2010-08-10
# 2010-08-17  1.000164  1.011142             4  2010-08-10
# 2010-08-18  1.000875  0.997934             5  2010-08-10
# ...              ...       ...           ...         ...
# 2013-02-14  0.998730  1.001649             1  2013-02-13
# 2013-02-19  1.000074  1.007910             2  2013-02-13
# 2013-02-20  1.002742  0.985612             3  2013-02-13
# 2013-02-21  1.002565  0.996682             4  2013-02-13
# 2013-02-25  0.993638  0.980680             5  2013-02-13
#
# [500 rows x 4 columns]

# %%
plt.figure(figsize=(45,15))
plt.plot(df['forecast'])
plt.plot(df['actuals'])
plt.legend(['forecast','actuals'],fontsize=30)

plt.show()

# %%
plt.figure(figsize=(45,15))
plt.scatter(df['forecast'],df['actuals'])
# plt.legend(['forecast','actuals'],fontsize=30)

plt.show()
