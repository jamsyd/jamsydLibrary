# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
annual_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\annual\soybean_meal_annual_statistics.csv',index_col='Year',parse_dates=True)
price_df  = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\daily\commodities\soft_commodities\grains\soybean_meal\CBOT_DL_ZM1!, 1D (1).csv',index_col='time',parse_dates=True)

# %%
annual_df.head()
# Out:
#             Beginning stocks  Production  Imports        TOTAL SUPPLY  \
# Year
# 1973-01-01               183       19674        0               19857
# 1974-01-01               507       16702        0               17209
# 1975-01-01               358       20754        0               21112
# 1976-01-01               355       18488        0               18843
# 1977-01-01               228       22371        0               22599
#
#             Domestic  Exports        TOTAL USAGE  ENDING STOCKS  STOCK/USE (%)
# Year
# 1973-01-01     13802     5548              19350            507       0.026202
# 1974-01-01     12552     4299              16851            358       0.021245
# 1975-01-01     15612     5145              20757            355       0.017103
# 1976-01-01     14056     4559              18615            228       0.012248
# 1977-01-01     16276     6080              22356            243       0.010870

# %%
annual_df.columns
# Out:
# Index(['Beginning stocks', 'Production', 'Imports', '      TOTAL SUPPLY',
#        'Domestic', 'Exports', '      TOTAL USAGE', 'ENDING STOCKS',
#        'STOCK/USE (%)'],
#       dtype='object')

# %%
plt.figure(figsize=(45,15))

plt.title('STOCK/USE (%)',fontsize=50)
plt.plot(1/annual_df['STOCK/USE (%)'])


plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('STOCKS/USE (%)',fontsize=50)
plt.plot(1/annual_df['STOCK/USE (%)'])

plt.twinx()

plt.plot(np.log(price_df['close']))
plt.show()

# %%
for column in annual_df.columns:

    plt.figure(figsize=(45,15))

    plt.title(column,fontsize=45)
    plt.plot(annual_df[column])

    plt.ylabel(column,fontsize=20)
    plt.xlabel('Year',fontsize=20)

    plt.show()
