# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
annual_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\annual\wheat_annual_statistics.csv',index_col='Year',parse_dates=True)
price_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\daily\commodities\soft_commodities\grains\wheat\CBOT_DL_ZW1!, 1D.csv',index_col='time',parse_dates=True)

# %%
annual_df.columns
# Out:
# Index(['Planted Acres', 'Harvested Acres', 'Yield', '% Harvested',
#        'Production', 'Stocks', 'Imports', '     TOTAL SUPPLY', 'Seed', 'Food',
#        'Feed & Residual', '     TOTAL DOM. USE', 'Grain Exports',
#        'Product Exports', '     TOTAL EXPORTS', '     TOTAL USAGE',
#        'ENDING STOCKS', 'Free', 'Reserve', 'Loan', 'CCC', 'STOCKS/USE (%)',
#        'Major Mkt. Prices ($/Bu.)'],
#       dtype='object')

# %%
annual_df.head()
# Out:
#             Planted Acres  Harvested Acres      Yield  % Harvested  \
# Year
# 1973-01-01         59.300             54.1  31.626617     0.912310
# 1974-01-01         71.044             65.4  27.247706     0.920556
# 1975-01-01         74.900             69.5  30.604317     0.927904
# 1976-01-01         80.400             70.9  30.310296     0.881841
# 1977-01-01         75.400             66.7  30.674663     0.884615
#
#             Production  Stocks  Imports       TOTAL SUPPLY   Seed   Food  ...  \
# Year                                                                      ...
# 1973-01-01      1711.0   597.0      3.0             2311.0   84.0  544.0  ...
# 1974-01-01      1782.0   340.0      3.0             2125.0   92.0  545.0  ...
# 1975-01-01      2127.0   435.0      2.0             2564.0  100.0  589.0  ...
# 1976-01-01      2149.0   666.0      3.0             2818.0   92.0  588.0  ...
# 1977-01-01      2046.0  1113.0      2.0             3161.0   80.0  587.0  ...
#
# ...

# %%
plt.figure(figsize=(45,15))

plt.title('STOCKS/USE (%)',fontsize=50)
plt.plot(1/annual_df['STOCKS/USE (%)'])

plt.twinx()

plt.plot(np.log(annual_df['Major Mkt. Prices ($/Bu.)']),color='red')
plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('STOCKS/USE (%)',fontsize=50)
plt.scatter((1/annual_df['STOCKS/USE (%)']).diff(1),np.log(annual_df['Major Mkt. Prices ($/Bu.)']).diff(1))

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('STOCKS/USE (%)',fontsize=50)
plt.plot(1/annual_df['STOCKS/USE (%)'])

plt.twinx()

plt.plot(np.log(price_df['close']))
plt.show()

# %%
for column in annual_df.columns:

    plt.figure(figsize=(45,15))

    plt.title(column,fontsize=45)
    plt.plot(annual_df[column])

    plt.ylabel(column,fontsize=20)
    plt.xlabel('Year',fontsize=20)

    plt.show()
