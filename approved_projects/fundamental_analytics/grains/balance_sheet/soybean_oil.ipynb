# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
annual_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\annual\soybean_oil_annual_statistics.csv',index_col='Year',parse_dates=True)
price_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\daily\commodities\soft_commodities\grains\soybean_oil\CBOT_DL_ZL1!, 1D (1).csv',index_col='time',parse_dates=True)

# %%
annual_df.head()
# Out:
#             Beginning stocks  Production  Imports        TOTAL SUPPLY  \
# Year
# 1973-01-01               516        8995        0                9511
# 1974-01-01               794        7376        0                8170
# 1975-01-01               561        9630        0               10191
# 1976-01-01              1251        8578        0                9829
# 1977-01-01               771       10288        0               11059
#
#             Domestic    For methyl ester    Bio-Diesel  Exports  \
# Year
# 1973-01-01      7282                   0             0     1435
# 1974-01-01      6581                   0             0     1028
# 1975-01-01      7964                   0             0      976
# 1976-01-01      7515                   0             0     1547
# 1977-01-01      8273                   0             0     2057
#
#                   TOTAL USAGE  ENDING STOCKS  STOCK/USE (%)  \
# Year
# 1973-01-01               8717            794       0.091086
# 1974-01-01               7609            561       0.073728
# 1975-01-01               8940           1251       0.139933
# 1976-01-01               9062            771       0.085081
# 1977-01-01              10330            729       0.070571
#
#             Average Price ($/Lb)
# Year
# 1973-01-01                   0.0
# 1974-01-01                   0.0
# 1975-01-01                   0.0
# 1976-01-01                   0.0
# 1977-01-01                   0.0

# %%
plt.figure(figsize=(45,15))

plt.title('STOCK/USE (%)',fontsize=50)
plt.plot(1/annual_df['STOCK/USE (%)'])

plt.twinx()

plt.plot(np.log(price_df['close']))
plt.show()

# %%
for column in annual_df.columns:

    plt.figure(figsize=(45,15))

    plt.title(column,fontsize=45)
    plt.plot(annual_df[column])

    plt.ylabel(column,fontsize=20)
    plt.xlabel('Year',fontsize=20)

    plt.show()
