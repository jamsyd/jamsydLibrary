# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
annual_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_projects\fundamental_analytics\ethanol\ethanol_production.csv',index_col="Date",parse_dates=True)
# price_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\daily\commodities\soft_commodities\grains\soybean_oil\CBOT_DL_ZL1!, 1D (1).csv',index_col='time',parse_dates=True)

# %%
annual_df.head()
# Out:
#            Date  \
# 0  Jun 04, 2010
# 1  Jun 11, 2010
# 2  Jun 18, 2010
# 3  Jun 25, 2010
# 4  Jul 02, 2010
#
#    Weekly U.S. Oxygenate Plant Production of Fuel Ethanol  (Thousand Barrels per Day)  \
# 0                                                839
# 1                                                839
# 2                                                846
# 3                                                832
# 4                                                855
#
#    Weekly East Coast (PADD 1) Oxygenate Plant Production of Fuel Ethanol  (Thousand Barrels per Day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Weekly Midwest (PADD 2) Oxygenate Plant Production of Fuel Ethanol  (Thousand Barrels per Day)  \
# 0                                                800
# 1                                                803
# 2                                                804
# 3                                                794
# 4                                                811
#
#    Weekly Gulf Coast (PADD 3) Oxygenate Plant Production of Fuel Ethanol  (Thousand Barrels per Day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Weekly Rocky Mountain (PADD 4) Oxygenate Plant Production of Fuel Ethanol  (Thousand Barrels per Day)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Weekly West Coast (PADD 5) Oxygenate Plant Production of Fuel Ethanol  (Thousand Barrels per Day)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
plt.figure(figsize=(45,15))

plt.title('STOCK/USE (%)',fontsize=50)
plt.plot(1/annual_df['STOCK/USE (%)'])

plt.twinx()

# plt.plot(np.log(price_df['close']))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'STOCK/USE (%)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3540\2330224700.py in <module>
#       2
#       3 plt.title('STOCK/USE (%)',fontsize=50)
# ----> 4 plt.plot(1/annual_df['STOCK/USE (%)'])
#       5
#       6 plt.twinx()
#
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\James Stanley\anaconda3\envs\airflow-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'STOCK/USE (%)'

# %%
for column in annual_df.columns:

    plt.figure(figsize=(45,15))

    plt.title(column,fontsize=45)
    plt.plot(annual_df[column])

    plt.ylabel(column,fontsize=20)
    plt.xlabel('Year',fontsize=20)

    plt.show()
# Out:
# The kernel failed to start due to the missing module 'dateutil'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.
