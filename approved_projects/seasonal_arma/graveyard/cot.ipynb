# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from statsmodels.tsa.arima_model import ARMA

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

from statsmodels.tsa.seasonal import seasonal_decompose

# %%
cot_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\daily\commodities\soft_commodities\grains\soybeans\ICEUS_DLY_KC1!, 1D.csv',parse_dates=True,index_col='time')

# %%
cot_df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'Commercials long', 'Commercials short',
#        'Commercials net', 'Large Speculators long', 'Large Speculators short',
#        'Large Speculators net', 'Small Speculators long',
#        'Small Speculators short', 'Small Speculators net', 'MA',
#        'Smoothing Line', 'Volume', 'Volume MA', 'OI', 'Commercials long.1',
#        'Commercials short.1', 'Commercials net.1', 'Large Speculators long.1',
#        'Large Speculators short.1', 'Large Speculators net.1',
#        'Small Speculators long.1', 'Small Speculators short.1',
#        'Small Speculators net.1'],
#       dtype='object')

# %%
cot_df['comnot_oi'] = cot_df['Commercials net.1']/cot_df['OI']

# %%
cot_df.dtypes
# Out:
# open                         float64
# high                         float64
# low                          float64
# close                        float64
# Commercials long             float64
# Commercials short            float64
# Commercials net              float64
# Large Speculators long       float64
# Large Speculators short      float64
# Large Speculators net        float64
# Small Speculators long       float64
# Small Speculators short      float64
# Small Speculators net        float64
# MA                           float64
# Smoothing Line               float64
# Volume                       float64
# Volume MA                    float64
# OI                           float64
# Commercials long.1           float64
# Commercials short.1          float64
# Commercials net.1            float64
# Large Speculators long.1     float64
# Large Speculators short.1    float64
# Large Speculators net.1      float64
# Small Speculators long.1     float64
# ...

# %%
# cot_df = cot_df.dropna(axis=0)

# %%
plt.figure(figsize=(45,15))

plt.plot(cot_df['Large Speculators net.1']/cot_df['OI'],color='red')
plt.twinx()
plt.plot(np.log(cot_df['close']))

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.scatter(-cot_df['comnot_oi'].diff(1),np.log(cot_df['close'].diff(1)))


plt.show()
