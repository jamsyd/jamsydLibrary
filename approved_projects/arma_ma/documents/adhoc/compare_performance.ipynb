# %% [markdown]
# # Compare model performance

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
metadata_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(3,3)\metadata_corn_(3, 3)_True_5.csv',parse_dates=True,index_col='asofdate')

# %%
df2 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(1,0)\tradeperformance_corn_arma_ma50_(1,0).csv')
df3 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(1,1)\tradeperformance_corn_arma_ma50_(1,1).csv')
df4 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(2,2)\tradeperformance_corn_arma_ma50_(2,2).csv')
df5 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(3,3)\tradeperformance_corn_arma_ma50_(3,3).csv')

# %%
tradeperformance_df = pd.concat([df2,df3,df4,df5])

# %%
tradeperformance_df
# Out:
#    Unnamed: 0  No._Trades  relative_Pnl  Hit_Rate  Minimum  Maximum      Mean  \
# 0           0        2599      1.996407  0.789838   -65.75   108.25  1.600991
# 0           0        2599      2.027954  0.793687   -65.75   108.25  1.617157
# 0           0        2599      2.022150  0.794536   -65.75   108.25  1.609080
# 0           0        1385      1.977207  0.611272   -65.75   108.25  2.915733
#
#      Variance    Std_Dev      Skew   Kurtosis
# 0  105.832570  10.287496       NaN        NaN
# 0  105.294197  10.261296       NaN        NaN
# 0  103.264109  10.161895  2.513053  23.266578
# 0  192.326906  13.868198       NaN        NaN

# %%
df_2 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(1,0)\metadatasummary_corn_arma_(1,0).csv')
df_3 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(1,1)\metadatasummary_corn_arma_(1,1).csv')
df_4 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(2,2)\metadatasummary_corn_arma_(2,2).csv')
df_5 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(3,3)\metadatasummary_corn_arma_(3,3).csv')

# %%
metadatasummary_df = pd.concat([df_2.T,df_3.T,df_4.T,df_5.T])

# %%
metadatasummary_df
# Out:
#                     0            1            2            3         4   \
# Unnamed: 0  Unnamed: 0          aic          bic         hqic       mae
# 0               1299.5 -1413.067224 -1402.478936 -1408.806716  0.011071
# Unnamed: 0  Unnamed: 0          aic          bic         hqic       mae
# 0               1297.5 -1412.718187 -1398.600471  -1407.03751  0.011041
# Unnamed: 0  Unnamed: 0          aic          bic         hqic       mae
# 0               1288.0 -1412.760865 -1391.584291  -1404.23985  0.010979
# Unnamed: 0  Unnamed: 0          aic          bic         hqic       mae
# 0               1242.0 -1408.571217 -1380.335784 -1397.209864  0.012475
#
#                   5         6                7     8              9   \
# Unnamed: 0       mse   rsquare  forecastHorizon  diff  trainDFLength
# 0           0.000247  0.995554              5.0   1.0          252.0
# Unnamed: 0       mse   rsquare  forecastHorizon  diff  trainDFLength
# ...

# %%
pnl_df1 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(1,0)\pnl_corn_arma_ma50_(1,0).csv',parse_dates=True,index_col='asofdate')
pnl_df2 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(1,1)\pnl_corn_arma_ma50_(1,1).csv',parse_dates=True,index_col='asofdate')
pnl_df3 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(2,2)\pnl_corn_arma_ma50_(2,2).csv',parse_dates=True,index_col='asofdate')
pnl_df4 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(3,3)\pnl.csv',parse_dates=True,index_col='asofdate')

# %% [markdown]
# # Compare PnL

# %%
plt.figure(figsize=(45,15))

plt.plot(pnl_df1['pnl'].cumsum())
plt.plot(pnl_df2['pnl'].cumsum())
plt.plot(pnl_df3['pnl'].cumsum())
plt.plot(pnl_df4['pnl'].cumsum())

plt.legend(['(1,0)','(1,1)','(2,2)','(3,3)'],fontsize=20)
plt.show()

# %%
plt.figure(figsize=(45,15))

plt.plot(pnl_df3['pnl'].cumsum() - pnl_df1['pnl'].cumsum())

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.plot(pnl_df3['pnl'].cumsum() - pnl_df2['pnl'].cumsum())

plt.show()

# %% [markdown]
# # Compare forecasts

# %%
forecast_df1 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(1,0)\forecasts_corn_(1, 0)_True_5.csv',parse_dates=True,index_col='asofdate')
forecast_df2 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(1,1)\forecasts_corn_(1, 1)_True_5.csv',parse_dates=True,index_col='asofdate')
forecast_df3 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(2,2)\forecasts_corn_(2, 2)_True_5.csv',parse_dates=True,index_col='asofdate')
forecast_df4 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(3,3)\forecasts_corn_(3, 3)_True_5.csv',parse_dates=True,index_col='asofdate')

# %%
plt.figure(figsize=(45,15))

plt.plot(forecast_df3['pointForecast'] - forecast_df4['pointForecast'])

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.plot(forecast_df3['pointForecast'] - forecast_df1['pointForecast'])

plt.show()

# %% [markdown]
# # Compare Metadata

# %%
metadata_df1 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(1,0)\metadata_corn_(1, 0)_True_5.csv',parse_dates=True,index_col='asofdate')
metadata_df2 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(1,1)\metadata_corn_(1, 1)_True_5.csv',parse_dates=True,index_col='asofdate')
metadata_df3 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma(2,2)\metadata_corn_(2, 2)_True_5.csv',parse_dates=True,index_col='asofdate')
metadata_df4 = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(3,3)\metadata_corn_(3, 3)_True_5.csv',parse_dates=True,index_col='asofdate')

# %%
plt.figure(figsize=(45,15))

plt.plot(metadata_df1['aic'])
plt.plot(metadata_df2['aic'])
plt.plot(metadata_df3['aic'])
plt.plot(metadata_df4['aic'])

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.plot(metadata_df1['bic'])
plt.plot(metadata_df2['bic'])
plt.plot(metadata_df3['bic'])
plt.plot(metadata_df4['bic'])

plt.show()

# %% [markdown]
# # Forecast relative to performance

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
forecast_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\forecasts_HECLA_(1, 1)_True_5.csv',parse_dates=True,index_col='asofdate')
pnl_df      = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\pnl_armaspreadthreshold_HECLA_(1, 1)_True_5.csv',parse_dates=True,index_col='asofdate')

# %%
for i in range(13):
    plt.figure(figsize=(45,15))

    plt.plot(forecast_df['close'][i*1000:(i+1)*1000])
    plt.plot(forecast_df['pointForecast'][i*1000:(i+1)*1000])
    plt.title('Forecasts',fontsize=40)
    plt.show()

    plt.figure(figsize=(45,15))

    plt.plot(pnl_df['pnl'][i*1000:(i+1)*1000].cumsum())
    plt.title('PnL',fontsize=40)
    plt.show()
