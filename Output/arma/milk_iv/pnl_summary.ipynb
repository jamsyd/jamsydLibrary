# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
forecast_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\Output\arma\crypto\chainlink\forecasts_chainlink_(2, 2)_True_5.csv',parse_dates=True,index_col='asofdate')
pnl_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\Output\arma\crypto\chainlink\pnl.csv',parse_dates=True,index_col='asofdate')

# %%
plt.figure(figsize=(45,15))

plt.plot(pnl_df['pnl'])

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('Profit and Loss',fontsize=45)
plt.plot(pnl_df['pnl'].cumsum())
plt.show()

# %%
forecast_df
# Out:
#                            Unnamed: 0  pointForecast      close  forecastday  \
# asofdate
# 2018-05-31 00:00:00+00:00           0       0.342377   0.343477            1
# 2018-06-01 00:00:00+00:00           1       0.345858   0.350758            2
# 2018-06-02 00:00:00+00:00           2       0.340390   0.367845            3
# 2018-06-03 00:00:00+00:00           3       0.332698   0.362294            4
# 2018-06-04 00:00:00+00:00           4       0.331851   0.338959            5
# ...                               ...            ...        ...          ...
# 2021-02-19 00:00:00+00:00         995      32.974590  34.719950            1
# 2021-02-20 00:00:00+00:00         996      32.803913  33.970000            2
# 2021-02-21 00:00:00+00:00         997      32.582595  34.148660            3
# 2021-02-22 00:00:00+00:00         998      32.762364  31.480010            4
# 2021-02-23 00:00:00+00:00         999      32.884181  25.948300            5
#
# ...

# %%
plt.figure(figsize=(45,15))

plt.plot(forecast_df['close'])
plt.plot(forecast_df['pointForecast'])

plt.legend(['close','pointForecast'],fontsize=45)

plt.show()
