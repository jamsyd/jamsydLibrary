# %% [markdown]
# # Metadata

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
metadata = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\Output\arma\soybeans\metadata.csv')

# %%
metadata.head()
# Out:
#    Unnamed: 0                   asofdate          aic          bic  \
# 0           0  1968-12-05 01:00:00+00:00 -2117.589667 -2103.471951
# 1           1  1968-12-12 01:00:00+00:00 -2118.157409 -2104.039693
# 2           2  1968-12-19 01:00:00+00:00 -2084.893170 -2070.775454
# 3           3  1968-12-27 01:00:00+00:00 -2088.553361 -2074.435645
# 4           4  1969-01-06 01:00:00+00:00 -2085.870492 -2071.752775
#
#           hqic       mae       mse   rsquare  forecastHorizon  log_diff  \
# 0 -2111.908990  0.002499  0.000013  1.001934                5      True
# 1 -2112.476733  0.002499  0.000013  1.001908                5      True
# 2 -2079.212493  0.002614  0.000014  0.994956                5      True
# 3 -2082.872685  0.002583  0.000014  0.999692                5      True
# 4 -2080.189815  0.002631  0.000014  0.997099                5      True
#
#    trainDFLength  num_models  order_p  order_q                    time  \
# 0            252       12000        1        1  0 days 00:00:00.706090
# 1            252       12000        1        1  0 days 00:00:00.621993
# 2            252       12000        1        1  0 days 00:00:01.362002
# 3            252       12000        1        1  0 days 00:00:00.776588
# 4            252       12000        1        1  0 days 00:00:00.915995
#
#    ar.L1.close  ma.L1.close
# 0          NaN          NaN
# 1     4.580518     4.658900
# 2     0.090998     0.071950
# 3          NaN          NaN
# 4     0.822659     0.799348

# %%
metadata.mean(axis=0)
# Out:
# Unnamed: 0          1198.500000
# aic                -1414.912474
# bic                -1400.794758
# hqic               -1409.231798
# mae                    0.011049
# mse                    0.000269
# rsquare                1.004211
# forecastHorizon        5.000000
# log_diff               1.000000
# trainDFLength        252.000000
# num_models         12000.000000
# order_p                1.000000
# order_q                1.000000
# ar.L1.close            0.451527
# ma.L1.close            0.452784
# dtype: float64

# %%
metadata.var(axis=0)
# Out:
# Unnamed: 0         4.794002e+05
# aic                2.925330e+04
# bic                2.925330e+04
# hqic               2.925330e+04
# mae                1.417687e-05
# mse                8.208173e-08
# rsquare            2.764165e-03
# forecastHorizon    0.000000e+00
# log_diff           0.000000e+00
# trainDFLength      0.000000e+00
# num_models         0.000000e+00
# order_p            0.000000e+00
# order_q            0.000000e+00
# ar.L1.close        2.981224e-01
# ma.L1.close        3.001831e-01
# dtype: float64

# %%
plt.figure(figsize=(45,15))

plt.title('aic',fontsize=40)

plt.hist(metadata['aic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('bic',fontsize=40)

plt.hist(metadata['bic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('hqic',fontsize=40)

plt.hist(metadata['hqic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ar.L1.close',fontsize=40)

plt.hist(metadata['ar.L1.close'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ar.L2.close',fontsize=40)

plt.hist(metadata['ar.L2.close'],bins=500)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ar.L2.close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-b797a7a845e9> in <module>
#       3 plt.title('ar.L2.close',fontsize=40)
#       4
# ----> 5 plt.hist(metadata['ar.L2.close'],bins=500)
#       6
#       7 plt.show()
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ar.L2.close'

# %%
plt.figure(figsize=(45,15))

plt.title('ma.L1.close',fontsize=40)

plt.hist(metadata['ma.L1.close'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ma.L2.close',fontsize=40)

plt.hist(metadata['ma.L2.close'],bins=500)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ma.L2.close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-9a1fce7120eb> in <module>
#       3 plt.title('ma.L2.close',fontsize=40)
#       4
# ----> 5 plt.hist(metadata['ma.L2.close'],bins=500)
#       6
#       7 plt.show()
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ma.L2.close'

# %%
plt.figure(figsize=(45,15))

plt.title('rsquare',fontsize=40)

plt.hist(metadata['rsquare'],bins=2000)

plt.show()
