# %% [markdown]
# # Metadata

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
metadata = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\Output\arma\corn\metadata.csv')

# %%
metadata.head()
# Out:
#    Unnamed: 0                   asofdate          aic          bic  \
# 0           0  1970-02-02 01:00:00+00:00 -1576.166087 -1554.989513
# 1           1  1970-02-09 01:00:00+00:00 -1575.661634 -1554.485059
# 2           2  1970-02-16 01:00:00+00:00 -1575.182464 -1554.005889
# 3           3  1970-02-24 01:00:00+00:00 -1575.317468 -1554.140894
# 4           4  1970-03-03 01:00:00+00:00 -1574.380738 -1553.204164
#
#           hqic       mae       mse   rsquare  forecastHorizon  log_diff  \
# 0 -1567.645072  0.006842  0.000107  0.947866                5      True
# 1 -1567.140619  0.006873  0.000107  0.947065                5      True
# 2 -1566.661449  0.006883  0.000108  0.948077                5      True
# 3 -1566.796453  0.006888  0.000108  0.949406                5      True
# 4 -1565.859723  0.006896  0.000108  0.948284                5      True
#
#    trainDFLength  num_models  order_p  order_q                    time  \
# ...

# %%
metadata.mean(axis=0)
# Out:
# Unnamed: 0          1188.500000
# aic                -1413.129632
# bic                -1391.953057
# hqic               -1404.608617
# mae                    0.011002
# mse                    0.000243
# rsquare                0.976037
# forecastHorizon        5.000000
# log_diff               1.000000
# trainDFLength        252.000000
# num_models         12000.000000
# order_p                2.000000
# order_q                2.000000
# ar.L1.close            0.259025
# ar.L2.close            0.211299
# ma.L1.close            0.260970
# ma.L2.close            0.224935
# dtype: float64

# %%
metadata.var(axis=0)
# Out:
# Unnamed: 0         4.714385e+05
# aic                2.060862e+04
# bic                2.060862e+04
# hqic               2.060862e+04
# mae                1.236005e-05
# mse                2.467442e-08
# rsquare            4.940483e-02
# forecastHorizon    0.000000e+00
# log_diff           0.000000e+00
# trainDFLength      0.000000e+00
# num_models         0.000000e+00
# order_p            0.000000e+00
# order_q            0.000000e+00
# ar.L1.close        9.268411e-01
# ar.L2.close        4.934784e-01
# ma.L1.close        9.455724e-01
# ma.L2.close        5.434498e-01
# dtype: float64

# %%
plt.figure(figsize=(45,15))

plt.title('aic',fontsize=40)

plt.hist(metadata['aic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('bic',fontsize=40)

plt.hist(metadata['bic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('hqic',fontsize=40)

plt.hist(metadata['hqic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ar.L1.close',fontsize=40)

plt.hist(metadata['ar.L1.close'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ar.L2.close',fontsize=40)

plt.hist(metadata['ar.L2.close'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ma.L1.close',fontsize=40)

plt.hist(metadata['ma.L1.close'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ma.L2.close',fontsize=40)

plt.hist(metadata['ma.L2.close'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('rsquare',fontsize=40)

plt.hist(metadata['rsquare'],bins=2000)

plt.show()

# %% [markdown]
# # Training time

# %%
plt.figure(figsize=(45,15))

plt.title('time',fontsize=40)

plt.hist(metadata['time'])

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('hqic',fontsize=40)

plt.plot(metadata['time'].cumsum())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-a2005807e120> in <module>
#       5 plt.plot(metadata['time'].cumsum())
#       6
# ----> 7 plt.show()
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# ~\AppData\Roaming\Python\Python39\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      38     try:
#      39         for figure_manager in Gcf.get_all_fig_managers():
# ---> 40             display(
#      41                 figure_manager.canvas.figure,
#      42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...
