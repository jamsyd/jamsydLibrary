# %% [markdown]
# # Metadata

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
metadata = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\Output\arma\commodities\soybean_oil\metadata_soybean_oil_(1, 1)_True_5.csv')

# %%
metadata.head()
# Out:
#    Unnamed: 0                   asofdate          aic          bic  \
# 0           0  2008-12-05 01:00:00+00:00 -1287.684739 -1273.567023
# 1           1  2008-12-12 01:00:00+00:00 -1313.411701 -1299.293985
# 2           2  2008-12-19 01:00:00+00:00 -1316.143284 -1302.025568
# 3           3  2008-12-29 01:00:00+00:00 -1318.183094 -1304.065377
# 4           4  2009-01-06 01:00:00+00:00 -1313.793137 -1299.675421
#
#           hqic       mae       mse   rsquare  forecastHorizon  diff  \
# 0 -1282.004063  0.012418  0.000342  0.993585                5  True
# 1 -1307.731025  0.011894  0.000309  0.991132                5  True
# 2 -1310.462608  0.011709  0.000306  0.989228                5  True
# 3 -1312.502417  0.011623  0.000303  0.988730                5  True
# 4 -1308.112461  0.011608  0.000309  0.985440                5  True
#
#    trainDFLength  num_models  order_p  order_q                    time  \
# 0            252        3300        1        1  0 days 00:00:00.762080
# 1            252        3300        1        1  0 days 00:00:00.854384
# 2            252        3300        1        1  0 days 00:00:00.572678
# 3            252        3300        1        1  0 days 00:00:00.696409
# 4            252        3300        1        1  0 days 00:00:00.759987
#
#      product_name  ar.L1.close  ma.L1.close
# 0  newcastle_coal     0.525583     0.519214
# 1  newcastle_coal     0.362046     0.353335
# 2  newcastle_coal     0.348429     0.338682
# 3  newcastle_coal     0.344922     0.334642
# 4  newcastle_coal     0.324191     0.320531

# %%
metadata.mean(axis=0)
# Out:
# Unnamed: 0          328.000000
# aic               -1499.762778
# bic               -1485.645062
# hqic              -1494.082102
# mae                   0.007671
# mse                   0.000271
# rsquare               0.983717
# forecastHorizon       5.000000
# diff                  1.000000
# trainDFLength       252.000000
# num_models         3300.000000
# order_p               1.000000
# order_q               1.000000
# ar.L1.close           0.374147
# ma.L1.close           0.379877
# dtype: float64

# %%
metadata.var(axis=0)
# Out:
# Unnamed: 0         3.602550e+04
# aic                5.681861e+04
# bic                5.681861e+04
# hqic               5.681861e+04
# mae                1.673281e-05
# mse                2.205362e-07
# rsquare            1.219849e-03
# forecastHorizon    0.000000e+00
# diff               0.000000e+00
# trainDFLength      0.000000e+00
# num_models         0.000000e+00
# order_p            0.000000e+00
# order_q            0.000000e+00
# ar.L1.close        8.750652e-02
# ma.L1.close        8.911337e-02
# dtype: float64

# %%
plt.figure(figsize=(45,15))

plt.title('aic',fontsize=40)

plt.hist(metadata['aic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('bic',fontsize=40)

plt.hist(metadata['bic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('hqic',fontsize=40)

plt.hist(metadata['hqic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ar.L1.close',fontsize=40)

plt.hist(metadata['ar.L1.close'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ar.L2.close',fontsize=40)

plt.hist(metadata['ar.L2.close'],bins=500)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ar.L2.close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-b797a7a845e9> in <module>
#       3 plt.title('ar.L2.close',fontsize=40)
#       4
# ----> 5 plt.hist(metadata['ar.L2.close'],bins=500)
#       6
#       7 plt.show()
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ar.L2.close'

# %%
plt.figure(figsize=(45,15))

plt.title('ma.L1.close',fontsize=40)

plt.hist(metadata['ma.L1.close'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('ma.L2.close',fontsize=40)

plt.hist(metadata['ma.L2.close'],bins=500)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ma.L2.close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-9a1fce7120eb> in <module>
#       3 plt.title('ma.L2.close',fontsize=40)
#       4
# ----> 5 plt.hist(metadata['ma.L2.close'],bins=500)
#       6
#       7 plt.show()
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\Users\James Stanley\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ma.L2.close'

# %%
plt.figure(figsize=(45,15))

plt.title('rsquare',fontsize=40)

plt.hist(metadata['rsquare'],bins=2000)

plt.show()

# %% [markdown]
# # Training time

# %%
plt.figure(figsize=(45,15))

plt.title('time',fontsize=40)

plt.hist(metadata['time'])

plt.show()
