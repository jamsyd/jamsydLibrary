# %% [markdown]
# # Metadata

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
metadata = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\approved_strategies\corn_arma_ma\output\arma_(3,3)\metadata_corn_(3, 3)_True_5.csv')

# %%
metadata.head()
# Out:
#    Unnamed: 0                   asofdate          aic          bic  \
# 0           0  1970-01-05 01:00:00+00:00 -1583.810425 -1555.574992
# 1           1  1970-01-12 01:00:00+00:00 -1582.307735 -1554.072302
# 2           2  1970-01-19 01:00:00+00:00 -1579.101939 -1550.866507
# 3           3  1970-01-26 01:00:00+00:00 -1581.530221 -1553.294788
# 4           4  1970-02-02 01:00:00+00:00 -1577.310148 -1549.074716
#
#           hqic       mae       mse   rsquare  forecastHorizon  diff  ...  \
# 0 -1572.449072  0.006665  0.000102  0.925075                5  True  ...
# 1 -1570.946382  0.006636  0.000103  0.927432                5  True  ...
# 2 -1567.740586  0.006812  0.000104  0.941557                5  True  ...
# 3 -1570.168868  0.006725  0.000103  0.923683                5  True  ...
# 4 -1565.948795  0.006869  0.000105  0.939902                5  True  ...
#
#    order_p  order_q                    time  product_name ar.L1.close  \
# 0        3        3  0 days 00:00:01.899741          corn    0.408328
# 1        3        3  0 days 00:00:01.174573          corn    0.357774
# 2        3        3  0 days 00:00:01.288052          corn    0.622504
# 3        3        3  0 days 00:00:01.364757          corn    0.314182
# 4        3        3  0 days 00:00:01.035818          corn    0.614892
#
#   ar.L2.close  ar.L3.close  ma.L1.close  ma.L2.close  ma.L3.close
# 0    0.072931     0.311011     0.430627     0.066138     0.392757
# 1    0.066481     0.312226     0.384542     0.068363     0.380892
# 2    0.231416     0.357345     0.617556     0.209650     0.394116
# 3    0.049815     0.271564     0.338545     0.037263     0.333754
# 4    0.231140     0.350850     0.610716     0.213894     0.388334
#
# [5 rows x 22 columns]

# %%
metadata.mean(axis=0).to_csv(f"""{metadata['product_name'][0]}_arma_({metadata['order_p'][0]},{metadata['order_q'][0]}).csv""")

# %%
metadata.var(axis=0)
# Out:
# Unnamed: 0         514809.166667
# aic                 24395.464032
# bic                 24395.464032
# hqic                24395.464032
# mae                     0.004438
# mse                     0.047992
# rsquare            153077.555829
# forecastHorizon         0.000000
# diff                    0.000000
# trainDFLength           0.000000
# num_models              0.000000
# order_p                 0.000000
# order_q                 0.000000
# ar.L1.close             0.114383
# ar.L2.close             0.111724
# ar.L3.close             0.086466
# ma.L1.close             0.115056
# ma.L2.close             0.121398
# ma.L3.close             0.095150
# dtype: float64

# %%
plt.figure(figsize=(45,15))

plt.title('aic',fontsize=40)

plt.hist(metadata['aic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('bic',fontsize=40)

plt.hist(metadata['bic'],bins=500)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('hqic',fontsize=40)

plt.hist(metadata['hqic'],bins=500)

plt.show()

# %%
metadata.columns
# Out:
# Index(['Unnamed: 0', 'asofdate', 'aic', 'bic', 'hqic', 'mae', 'mse', 'rsquare',
#        'forecastHorizon', 'diff', 'trainDFLength', 'num_models', 'order_p',
#        'order_q', 'time', 'product_name', 'ar.L1.close', 'ar.L2.close',
#        'ar.L3.close', 'ma.L1.close', 'ma.L2.close', 'ma.L3.close'],
#       dtype='object')

# %%
for i in range(1,metadata['order_p'][0]+1):

    plt.figure(figsize=(45,15))

    plt.title(f'ar.L{i}.close',fontsize=40)
    plt.hist(metadata[f'ar.L{i}.close'],bins=500)

    plt.show()

# %%
for i in range(1,metadata['order_q'][0]+1):

    plt.figure(figsize=(45,15))

    plt.title(f'ma.L{i}.close',fontsize=40)
    plt.hist(metadata[f'ma.L{i}.close'],bins=500)

    plt.show()
