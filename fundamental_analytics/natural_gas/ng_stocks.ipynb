# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
ngs_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\fundamental_analytics\natural_gas\ng_stocks.csv',parse_dates=True,index_col='Week ending')

# %%
ngs_df
# Out:
#                                    Source  East Region Midwest Region  \
# Week ending
# 2010-01-01   Derived EIA Weekly Estimates          769            900
# 2010-01-08   Derived EIA Weekly Estimates          703            820
# 2010-01-15   Derived EIA Weekly Estimates          642            750
# 2010-01-22   Derived EIA Weekly Estimates          616            710
# 2010-01-29   Derived EIA Weekly Estimates          582            661
# ...                                   ...          ...            ...
# 2022-12-30                        EIA-912          691            839
# 2023-01-06                        EIA-912          700            823
# 2023-01-13                        EIA-912          662            785
# 2023-01-20                        EIA-912          622            754
# 2023-01-27                        EIA-912          578            708
#
#              Mountain Region  Pacific Region South Central Region  Salt  \
# Week ending
# 2010-01-01               195             268                  985   159
# 2010-01-08               185             257                  886   123
# 2010-01-15               176             246                  793    91
# 2010-01-22               171             235                  789   102
# 2010-01-29               164             221                  779   108
# ...                      ...             ...                  ...   ...
# 2022-12-30               157             165                1,040   270
# 2023-01-06               153             160                1,067   295
# 2023-01-13               147             157                1,069   307
# 2023-01-20               140             150                1,067   310
# 2023-01-27               132             140                1,025   297
#
#             NonSalt Total Lower 48
# Week ending
# 2010-01-01      826          3,117
# 2010-01-08      763          2,850
# 2010-01-15      702          2,607
# 2010-01-22      687          2,521
# 2010-01-29      671          2,406
# ...             ...            ...
# 2022-12-30      770          2,891
# 2023-01-06      772          2,902
# 2023-01-13      762          2,820
# 2023-01-20      757          2,734
# 2023-01-27      728          2,583
#
# [683 rows x 9 columns]

# %%
ngs_df.columns
# Out:
# Index(['Source', 'East Region', 'Midwest Region', 'Mountain Region',
#        'Pacific Region', 'South Central Region', 'Salt', 'NonSalt',
#        'Total Lower 48'],
#       dtype='object')

# %%
cols = ['East Region', 'Midwest Region', 'Mountain Region',
       'Pacific Region', 'South Central Region', 
       'Total Lower 48']

# %%
cols = ['East Region','Mountain Region',
       'Pacific Region','Salt']

# %%
ngs_df = ngs_df[ngs_df['Source']=='EIA-912']

# %%
for col in cols:
    plt.figure(figsize=(45,15))
    plt.title(col)
    plt.plot(ngs_df[col])
    plt.show()

# %%
from statsmodels.tsa.arima_model import ARMA

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

from statsmodels.tsa.seasonal import seasonal_decompose

# %%
for col in cols:
    seasonal_result = seasonal_decompose(ngs_df[col], model="additive",period=52)
    seasonal = seasonal_result.seasonal
    plt.figure(figsize=(45,15))
    plt.title(col)
    plt.plot(seasonal)
    plt.show()

# %%
for col in cols:
    seasonal_result = seasonal_decompose(ngs_df[col], model="additive",period=52)
    residual = seasonal_result.resid
    plt.figure(figsize=(45,15))
    plt.title(col)
    plt.plot(residual)
    plt.show()

# %%
for col in cols:

    seasonal_result = seasonal_decompose(ngs_df[col], model="additive",period=52)
    residual = seasonal_result.resid
    diff = residual.reset_index().dropna(axis=0)

    plot_acf(diff['resid'], alpha=1, lags=5).savefig(f"{col}.jpg")

# %%
for col in cols:

    seasonal_result = seasonal_decompose(ngs_df[col], model="additive",period=52)
    residual = seasonal_result.resid
    diff = residual.reset_index().dropna(axis=0)

    plot_pacf(diff['resid'], alpha=1, lags=5).savefig(f"{col}.jpg")
