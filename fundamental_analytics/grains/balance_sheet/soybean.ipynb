# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
annual_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\annual\soybean_annual_statistics.csv',index_col='Year',parse_dates=True)
price_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\daily\commodities\soft_commodities\grains\soybeans\CBOT_DL_ZS1!, 1D.csv',index_col='time',parse_dates=True)

# %%
annual_df.columns
# Out:
# Index(['Planted Acres', 'Harvested Acres', 'Yield', '% Harvested',
#        'Production', 'Stocks', 'Imports', '      TOTAL SUPPLY', 'Crush',
#        'Seed', 'Feed & Residual', '      ALL DOM. USE', '      EXPORTS',
#        '      TOTAL USAGE', 'ENDING STOCKS', 'Free', 'CCC', 'Loan',
#        'STOCK/USE (%)'],
#       dtype='object')

# %%
annual_df.head()
# Out:
#             Planted Acres  Harvested Acres      Yield  % Harvested  \
# Year
# 1973-01-01           56.5             55.7  27.791741     0.985841
# 1974-01-01           52.5             51.3  23.703704     0.977143
# 1975-01-01           54.6             53.6  28.899254     0.981685
# 1976-01-01           50.3             49.4  26.093117     0.982107
# 1977-01-01           59.0             57.8  30.570934     0.979661
#
#             Production  Stocks  Imports        TOTAL SUPPLY  Crush  Seed  \
# Year
# 1973-01-01      1548.0    60.0      0.0              1608.0  821.0    56
# 1974-01-01      1216.0   171.0      0.0              1387.0  701.0    57
# 1975-01-01      1549.0   188.0      0.0              1737.0  865.0    53
# 1976-01-01      1289.0   246.0      0.0              1535.0  790.0    63
# 1977-01-01      1767.0   104.0      0.0              1871.0  927.0    69
#
#             Feed & Residual        ALL DOM. USE        EXPORTS  \
# Year
# ...

# %%
plt.figure(figsize=(45,15))

plt.title('STOCK/USE (%)',fontsize=50)
plt.plot(1/annual_df['STOCK/USE (%)'])

plt.twinx()

plt.plot(np.log(price_df['close']))
plt.show()

# %%
for column in annual_df.columns:

    plt.figure(figsize=(45,15))

    plt.title(column,fontsize=45)
    plt.plot(annual_df[column])

    plt.ylabel(column,fontsize=20)
    plt.xlabel('Year',fontsize=20)

    plt.show()
