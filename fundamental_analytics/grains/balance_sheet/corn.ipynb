# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
annual_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\annual\corn_annual_statistics.csv',index_col='Year',parse_dates=True)
price_df = pd.read_csv(r'C:\Users\James Stanley\Documents\GitHub\backtest_utilities\data\daily\commodities\soft_commodities\grains\corn\CBOT_DL_ZC1!, 1D.csv',index_col='time',parse_dates=True)

# %%
annual_df.columns
# Out:
# Index(['SEP/AUG YEAR #', 'Planted Acres (millions)',
#        'Harvested Acres (Millions)', 'Yield (bushels per acre)',
#        ' Harvested/Planted Acres', 'Production (millions)',
#        'Stocks (millions)', 'Imports (million)',
#        '      TOTAL SUPPLY (millions)',
#        'Acres devoted to ethanol production (millions)', 'Seed',
#        'Food, Alcohol & Industrial', '    ethanol for fuel',
#        'Growth in corn used for ethanol', 'Feed & Residual',
#        '      ALL DOM. USE', '      EXPORTS', '      TOTAL USAGE',
#        'ENDING STOCKS', 'Ending Stocks adj. for DDG's', 'Free', 'Reserve',
#        'CCC', 'Loan', 'STOCK/USE (%)', 'close'],
#       dtype='object')

# %%
annual_df.head()
# Out:
#            SEP/AUG YEAR #  Planted Acres (millions)  \
# Year
# 1973-01-01          73/74                      72.3
# 1974-01-01          74/75                      77.9
# 1975-01-01          75/76                      78.7
# 1976-01-01          76/77                      84.6
# 1977-01-01          77/78                      84.3
#
#             Harvested Acres (Millions)  Yield (bushels per acre)  \
# Year
# 1973-01-01                        62.1                 91.320451
# 1974-01-01                        65.4                 71.880734
# 1975-01-01                        67.6                 86.405325
# 1976-01-01                        71.5                 87.958042
# 1977-01-01                        71.6                 90.851955
#
#              Harvested/Planted Acres  Production (millions)  \
# Year
# 1973-01-01                  0.858921                 5671.0
# 1974-01-01                  0.839538                 4701.0
# ...

# %%
plt.figure(figsize=(45,15))

plt.title('Average Farm Price vs. Stock to use (%)',fontsize=45)
plt.scatter(annual_df['close'],1/annual_df['STOCK/USE (%)'])

plt.xlabel('Average Farm Price',fontsize=20)
plt.ylabel('Stock to use (%)',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('STOCK/USE (%)',fontsize=50)
plt.plot(1/annual_df['STOCK/USE (%)'])

plt.twinx()

plt.plot(np.log(price_df['close']))
plt.show()

# %%
### Add linear regression model from statsmodels and plot its results

### Try plotting log diff

# %%
plt.figure(figsize=(45,15))

plt.title('Planted Acres (millions)',fontsize=45)
plt.plot(annual_df['Planted Acres (millions)'])

plt.xlabel('Planted Acres (millions)',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('Harvested Acres (Millions)',fontsize=45)
plt.plot(annual_df['Harvested Acres (Millions)'])

plt.xlabel('Harvested Acres (Millions)',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('Yield (bushels per acre)',fontsize=45)
plt.plot(annual_df['Yield (bushels per acre)'])

plt.xlabel('Yield (bushels per acre)',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title(' Harvested/Planted Acres',fontsize=45)
plt.plot(annual_df[' Harvested/Planted Acres'])

plt.xlabel(' Harvested/Planted Acres',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('Production (millions)',fontsize=45)
plt.plot(annual_df['Production (millions)'])

plt.xlabel('Production (millions)',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('Stocks (millions)',fontsize=45)
plt.plot(annual_df['Stocks (millions)'])

plt.xlabel('Stocks (millions)',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('Imports (million)',fontsize=45)
plt.plot(annual_df['Imports (million)'])

plt.xlabel('Imports (million)',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(45,15))

plt.title('      TOTAL SUPPLY (millions)',fontsize=45)
plt.plot(annual_df['      TOTAL SUPPLY (millions)'])

plt.xlabel('      TOTAL SUPPLY (millions)',fontsize=20)

plt.show()
